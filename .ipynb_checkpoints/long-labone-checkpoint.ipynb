# %%
from IPython.display import IFrame, Image, HTML, display, YouTubeVideo
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 8, 4
from matplotlib.patches import Ellipse, Circle
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import mpl_toolkits.mplot3d.art3d as art3d
from mpl_toolkits.mplot3d import proj3d
from ipywidgets import interact, interactive, fixed
import pysal as ps
import pysal.spatial_dynamics.interaction as interaction

# %%
# %%HTML
# <img src="https://media.giphy.com/media/ryQboen5oMGly/giphy.gif">
# <h1> Brooke Long - Lab One </h1> <br>
# <i> No Satans were harmed during the creation of this notebook</i>
# <p> Its October; nothing celebrates the spirit of spook like Morticia Addams <br>
#
# Data used was created by the fine folks at the <a href="https://homofobiamata.wordpress.com/estatisticas/relatorios/"> Homofobia Mata </a> Wordpress

# %%
# The Data
url = "https://docs.google.com/spreadsheets/d/1_pQEpjf6_1Ykw_I8kX_qbvxyByJwOmUFd872Of2M3yw/pub?output=csv"
matas = pd.read_csv(url)
matas.head()
# Out:
#    N  N.1      MES  UF         CIDADE REGIÃO METROPOLITANA  \
# 0  1  1.0  Janeiro  MG   Juiz de Fora                  NaN
# 1  2  2.0  Janeiro  MS          Coxim                  NaN
# 2  3  3.0  Janeiro  MS        Caarapó                  NaN
# 3  4  4.0  Janeiro  SP    São Vicente  RM Baixada Santista
# 4  5  5.0  Janeiro  MG  Astolfo Dutra                  NaN
#
#                                               NOME        GLT  IDADE     COR  \
# 0                    FLÁVIO AUGUSTO ADARIO RIBEIRO        Gay   42.0     NaN
# 1  VERÔNICA BISMARCK (Douglas dos Santos Pinheiro)     Trans*   20.0  Branco
# 2           WAGNER ARAÚJO CONCEIÇÃO DA PURIFICAÇÃO        Gay   21.0   Pardo
# 3                             IDALÉCIO FONTES REGO        Gay   46.0  Branco
# 4                             JÚLIO CÉSAR DA SILVA  Bissexual   23.0  Branco
#
#   DROGA    PROFISSÁO          CAUSA MORTIS  GOLPES                    LOCAL
# ...

# %%
tidyoop = pd.melt(matas, id_vars=["MES","NOME","GLT","IDADE","COR","UF","CIDADE","DROGA","PROFISSÁO","CAUSA MORTIS", "GOLPES", "LOCAL","REGIÃO METROPOLITANA","N.1"],
                      value_name="N")
tidyoop
# Out:
#           MES                                               NOME        GLT  \
# 0     Janeiro                      FLÁVIO AUGUSTO ADARIO RIBEIRO        Gay
# 1     Janeiro    VERÔNICA BISMARCK (Douglas dos Santos Pinheiro)     Trans*
# 2     Janeiro             WAGNER ARAÚJO CONCEIÇÃO DA PURIFICAÇÃO        Gay
# 3     Janeiro                               IDALÉCIO FONTES REGO        Gay
# 4     Janeiro                               JÚLIO CÉSAR DA SILVA  Bissexual
# 5     Janeiro                                    VALDOMIRO MAGNO        Gay
# 6     Janeiro                             GILMAR BONFIM DE JESUS        Gay
# 7     Janeiro                                   NÃO IDENTIFICADO        Gay
# 8     Janeiro                                   NÃO IDENTIFICADA     Trans*
# 9     Janeiro                                   NÃO IDENTIFICADA     Trans*
# 10    Janeiro                     "JUJU" Jurandir Pereira Soares     Trans*
# ...

# %%
# %%HTML
# <h1> I decided I dont like this data </h1> <br>
# So heres another flavor

# %%
url = "https://docs.google.com/spreadsheets/d/18dAhJFUets1PO-bSQwRehOMGIlG_jUocmhlpvBHRmVc/pub?output=csv"
simple = pd.read_csv(url)
simple.head()
# Out:
#   Number  UF       LGBT    Month
# 0      1  MG        Gay  Janeiro
# 1      2  MS     Trans*  Janeiro
# 2      3  MS        Gay  Janeiro
# 3      4  SP        Gay  Janeiro
# 4      5  MG  Bissexual  Janeiro

# %%
PATH = "/Users/brooke/Documents/Spacetime/Tidy-Data-Carson/"
Image(filename = PATH + "matao.png", width=500, height=500)
Image(filename = PATH + "matam.png", width=500, height=500)
Image(filename = PATH + "matast.png", width=500, height=500)
Image(filename = PATH + "heatmap.png", width=500, height=500)

# %%
Image(filename = PATH + "matao.png", width=500, height=500)

# %%
Image(filename = PATH + "matam.png", width=500, height=500)

# %%
Image(filename = PATH + "matast.png", width=500, height=500)

# %%
$e^{i\pi} + 1 = 0$

# %%
# %%HTML
# <h1> Now wasnt that fun? </h1>
# <img src="https://media.giphy.com/media/spxsnvjlv4OnS/giphy.gif">
